# %% [markdown]
# 앞서 7개의 생선을 분류해내는 모델을 훈련하였다.
# 이제는 훈련 데이터가 조금씩 새로 전달되고 새로 추가되는 생선의 종류도 존재한다. 어떻게 모델을 지속적으로 운영이 가능할까?
# 기존의 훈련 데이터에 새로운 데이터를 계속 추가하여 매일매일 훈련하는건 어떨까?
# 하지만 이는 시간이 지날수록 데이터가 늘어나고 서버의 추가 등 현실적인 제한점이 존재한다.
# 또 다른 방법은 새로운 데이터를 추가할 때 이전 데이터를 버림으로서 훈련 데이터의 크기를 일정하게 유지하는 것이다.
# 하지만 이 방법은 중요한 데이터의 손실이 발생할 수 있는 문제가 있다.
# 위에서 언급한 두 방법은 이전에 훈련한 모델을 버리고 다시 새로운 모델을 훈련하는 방법이다. 앞서 훈련한 모델을 버리지 않고 새로운 데이터에 대해서만 조금씩 더 훈련할 수 없을까? 이렇게 할 수 있다면 훈련에 사용한 데이터를 모두 유지할 필요도 없고 앞서 학습한 생선을 까먹을 일도 없을 것이다.
#
# 이런 식의 훈련 방식을 **점진적 학습**또는 온라인 학습이라고 부른다. 대표적인 점진적 학습 알고리즘은 **확률적 경사 하강법(Stochastic Gradient Decendent)**이다. 사이킷 런에서는 확률적 경사 하강법을 위한 클래스를 제공한다.

# %% [markdown]
# ### 확률적 경사 하강법
# 확률적 - 무작위하게, 랜덤하게
# 경사 - 기울기
# 하강법 - 내려가는 방법
# 즉 경사를 따라 내려가는 방법을 의미한다.
#
# 가장 가파른 경사를 따라 원하는 지점에 도달하는 것이 목표이며 걸음이 너무 크다면 경사를 따라 내려가지 못하고 오히려 올라갈 수도 있다. 그렇기 때문에 조금씩 내려오는 것이 중요하며 이렇게 내려오는 과정이 경사 하강법 모델을 훈련하는 것이다.
# 확률적이라는 단어는 무엇을 뜻하는가?
# 훈련 세트를 사용해 모델을 훈련하기 때문에 경사 하강법도 훈련 세트를 사용하여 가장 가파른 길을 찾을 것이다. 이때 전체 샘플을 사용하지 않고 하나의 샘플을 훈련 세트에서 랜덤하게 골라 가장 가파른 길을 찾는다. 훈련 세트에서 랜덤하게 하나의 샘플을 고르는 것이 확률적 경사 하강법이다.
# 확률적 경사 하강법은 훈련 세트에서 랜덤하게 하나의 샘플을 선택하여 가파른 경사를 조금 내려간다. 그다음 훈련 세트에서 랜덤하게 또 다른 샘플을 하나 선택하여 경사를 조금 내려간다. 이런 방법으로 전체 샘플을 모두 사용할 때까지 계속한다.
# 모든 샘플을 다 사용하고도 다 내려오지 못한다면 다시 처음부터 시작한다. 훈련 세트에 모든 샘플을 다시 채워넣고 다시 랜덤하게 하나의 샘플을 선택해 이어서 경사를 내려간다. 만족할만한 위치에 도달할 때까지 계속 내려간다.
# 확률적 경사 하강법에서 훈련 세트를 한번 모두 사용하는 과정을 **에포크(epoch)**라고 부른다. 일반적으로 경사 하강법은 수십, 수백번 이상 에포크를 수행한다.

# %% [markdown]
# 1개씩 말고 무작위로 몇 개의 샘플을 선택해서 경사를 따라 내려가면 더 안정적일 것이다. 이렇게 여러 개의 샘플을 사용해 경사 하강법을 수행하는 방식을 **미니배치 경사 하강법(minibatch gradient descent)라고 한다.
# 한 번 경사로를 따라 이동하기 위해 전체 샘플을 사용할 수도 있다. 이를 **배치 경사 하강법(batch gradient descent)**이라고 한다. 전체 데이터를 이용하기 때문에 가장 안정적인 방법이지만 전체 데이터를 사용하면 그 만큼 컴퓨터 자원을 많이 사용하게 된다.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 확률적 경사 하강법은 훈련 세트를 사용해 아래에 있는 최적의 장소로 조금씩 이동하는 알고리즘이므로 훈련 데이터가 모두 준비되어 있지 않고 매일매일 업데이트 되어도 학습을 계속 이어나갈 수 있다.

# %% [markdown]
# 확률적 경사 하강법을 사용하는 알고리즘으로서 신경망 모델이 있다. 신경망 모델은 확률적 경사 하강법이나 미니배치 경사 하강법을 사용한다.

# %% [markdown]
# 어디서 내려가야 하는가? 가장 빠른 길을 찾아 내려가려고 하는 이 산은 무엇일까? 이 산이 바로 손실 함수라고 부르는 것이다.
#
# ---
#
# ### 손실 함수
# **손실 함수(loss function)**는 어떤 문제에서 머신러닝 알고리즘이 얼마나 엉터리인지를 측정하는 기준이다. 손실 함수의 값이 작을수록 좋고 어떤 값이 최솟값인지는 알지 못하기 때문에 가능한 만큼 찾아보고 만족할 수준에서 다 내려왔다고 판단해야한다. 이 값을 찾아서 조금씩 이동하려면 확률적 경사 하강법이 적절하다.
# 많은 문제에 대한 손실 함수는 이미 많이 정의되어 있기 때문에 생선을 분류하기 위해서는 어떤 손실 함수를 사용하는지 알아보자.

# %% [markdown]
# #### 비용 함수?
# 비용 함수(cost function)는 손실 함수의 다른 말이다. 엄밀히는 손실 함수는 샘플 하나에 대한 손실을 정의하고 비용 함수는 훈련 세트에 있는 모든 샘플에 대한 손실 함수의 합을 말한다. 하지만 이 둘을 엄격히 구분하지 않고 사용한다.

# %% [markdown]
# 분류에서 손실은 확실하다. 정답을 못 맞히는 것이다. 예를 들어 도미와 빙어를 구분하는 이진 분류 문제라면 도미는 양성 클래스(1), 빙어는 음성 클래스(0)라고 가정했을 시 아래와 같이 예측과 정답이 있다고 생각해보자.
#
# 예측          정답(타깃)
# 1      =      1
# 0      =/     1
# 0      =      0
# 1      =/     0

# %% [markdown]
# 정확도는 얼마일까? 4개의 예측 중에 2개만 맞았으므로 정확도는 0.5이다. 정확도를 손실 함수로 사용할 수 있을까?
# 예를 들어 정확도에 음수를 취하면 -1.0이 가장 낮고 -0.0이 가장 높다. 하지만 정확도에는 치명적인 단점이 있다. 예를 들어 앞의 그림과 같이 4개의 샘플만 있다면 가능한 정확도는 0, 0.25, 0.5, 0.75, 1 다섯 가지 뿐이다. 경사 하강법을 사용할 때 조금씩 내려와야 하는데 정확도가 듬성듬성하다면 경사 하강법을 통해 조금씩 움직일 수 없다.
# 경사면은 연속적이어야 하며 즉, 손실 함수는 미분 가능해야 한다.
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# 어떻게 연속적인 손실 함수를 만들 수 있을까? '로지스틱 회귀'에서 로지스틱 회귀 모델이 확률을 출력했었다. 예측은 0 또는 1이지만 확률은 0 ~ 1 사이의 어떤 값도 될 수 있었다. 즉 연속적이다.
# 위의 샘플 4개의 예측 확률을 각각 0.9, 0.3, 0.2, 0.8이라고 가정해보고 첫 번째 샘플부터 하나씩 어떻게 손실 함수를 만들 수 있는지 알아보자.

# %% [markdown]
# #### 로지스틱 손실 함수
# 첫 번째 샘플의 예측은 0.9이므로 양성 클래스의 타깃인 1과 곱한 다음 음수로 바꿀 수 있다. 이 경우 예측이 1에 가까울수록 좋은 모델이다. 예측이 1에 가까울수록 예측과 타깃의 곱의 음수는 점점 작아지므로 이 값을 손실 함수로 사용해도 괜찮다.
# ![image.png](attachment:image.png)
# 두 번째 샘플의 예측은 0.3이다. 타깃이 양성 클래스(1)인데 거리가 멀다. 위와 마찬가지로 예측과 타깃을 곱해 음수로 바꿔보자. 이 값은 -0.3이 되기 때문에 첫 번째 샘플보다 높은 손실이 된다.
# ![image-2.png](attachment:image-2.png)
# 세 번째 샘플을 보자. 이 샘플의 타깃은 음성 클래스이기 때문에 0이다. 이 값을 예측 확률인 0.2와 그대로 곱해서는 안된다. 무조건 0이 되기 때문이다. 한 가지 방법은 타깃을 마치 양성 클래스처럼 바꾸어 1로 만드는 것이다. 대신 예측값도 양성 클래스에 대한 예측으로 바꾼다. 즉 1 -0.2 = 0.8로 사용한다. 그 다음 곱하고 음수로 바꾸는 것은 동일하다.
# ![image-4.png](attachment:image-4.png)
# 세 번째 샘플은 음성 클래스인 타깃을 맞추었으므로 손실이 낮아야하고 -0.8로 낮은 손실이다. 네 번째 샘플을 보자. 네 번째 샘플도 타깃은 음성 클래스이고 정답을 맞추지 못했다. 타깃을 1로 바꾸고 예측 확률을 1에서 뺀 다음 곱해서 음수로 바꾸어 보자.
# ![image-5.png](attachment:image-5.png)
#
# 이런 방식으로 계산하면 연속적인 손실 함수를 얻을 수 있다. 여기에 로그 함수를 적용하면 더 좋다. 예측 확률의 범위는 0 ~ 1 사이인데 로그 함수는 이 사이에서 음수가 되므로 앞에 - 부호를 붙이면 최종 손실 값은 양수가 된다. 또한 로그 함수는 0에 가까울수록 큰 음수가 되기 때문에 손실을 아주 크게 만들 수 있다.
# ![image-6.png](attachment:image-6.png)
#
# 정리해보면, 양성 클래스(타깃 = 1)일 때 손실은 -log(예측 확률)로 계산한다. 확률이 1에서 멀어질수록 손실은 아주 큰 양수가 된다. 음성 클래스(타깃 = 0)일 때 손실은 -log(1 - 예측 확률)로 계산한다. 이 예측 확률이 0에서 멀어질수록 손실은 야주 큰 양수가 된다.

# %% [markdown]
# 이러한 손실 함수를 **로지스틱 손실 함수(logistic loss function)**라고 부른다. 또는 **이진 크로스엔트로피 손실 함수(binary cross-entropy loss function)**라고도 부른다.
# 이진 분류를 예로 들어 설명했지만 다중 분류도 비슷한 손실 함수를 사용한다. 다중 분류에서 사용하는 손실 함수를 **크로스엔트로피 손실 함수(cross-entropy loss function)**라고 부른다.
# 손실 함수를 직접 만드는 일은 없다. 이미 문제에 잘 맞는 손실 함수가 개발되어 있기 때문이다. 이진 분류는 로지스틱 손실 함수를 사용하고 다중 분류는 크로스엔트로피 손실 함수를 사용한다.

# %% [markdown]
# 그렇다면 회귀에는 어떤 손실 함수를 사용할까?
# 회귀의 손실 함수로는 3장에서 소개한 평균 절댓값 오차를 사용할 수 있다. 타깃에서 예측을 뺀 절댓값을 모든 샘플에 평균한 값이다. 또는 **평균 제곱 오차(mean squared error)**를 많이 사용한다. 타깃에서 예측을 뺀 값을 제곱한 다음 모든 샘플에 평균한 값이다. 이 값이 작을수록 좋은 모델이다.

# %% [markdown]
# ### 확률적 경사 하강법을 사용한 분류모델 만들기
# 모델을 생성하기에 앞서 훈련 세트와 테스트 세트의 특성을 표준화 전처리 해야한다. 그래야 각 특성값들이 동일한 스케일 값을 가져, 값이 큰 특정 특성에 의한 하강 효과가 다른 특성들에 비해 크게 산정되는 상황을 피할 수 있다.

# %%
import pandas as pd
fish = pd.read_csv('https://bit.ly/fish_csv_data')

# %% [markdown]
# Species 열을 제외한 나머지 5개는 입력 데이터로 사용한다. Species 열은 타깃 데이터다.

# %%
fish_input = fish[['Weight', 'Length', 'Diagonal', 'Height', 'Width']].to_numpy()
fish_target = fish['Species'].to_numpy()

# %% [markdown]
# 사이킷런의 train_test_split() 함수를 사용해 데이터를 훈련 세트와 테스트 세트로 나눈다.

# %%
from sklearn.model_selection import train_test_split
train_input, test_input, train_target, test_target = train_test_split(fish_input, fish_target, random_state = 42)

# %% [markdown]
# 앞서 언급한 표준화 전처리를 수행하자. 꼭 훈련 세트에서 학습한 통계 값으로 테스트 세트도 변환해야 한다.

# %%
from sklearn.preprocessing import StandardScaler
ss = StandardScaler()
ss.fit(train_input)
train_scaled = ss.transform(train_input)
test_scaled = ss.transform(test_input)
